# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# /var/folders/j1/8jxgjxxs6p196bswg6_4r8cm0000gn/T/ipykernel_2589/3034448462.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %% [markdown]
# # Data Profiling

# %%
# Load the data
customers_df = pd.read_csv('customers.csv')

# %%
customers_df
# Out:
#      Unnamed: 0 ﻿customerid      entity     name     surname  birth_date  sex  \
# 0             0       C0110  Individual   Kareem         Liu   5/11/1968    F
# 1             1       C0010  Individual  Trystan     Oconnor  11/26/1962    M
# 2             2       C0132  Individual     Kale         Gay    4/7/1959    M
# 3             3       C0137  Individual  Russell       Gross  11/25/1959    M
# 4             4       C0174     Company  Marleez          Co         NaN  NaN
# ..          ...         ...         ...      ...         ...         ...  ...
# 157         157       C0170  Individual     Emmy       Singh   12/3/1979    F
# 158         158       C0138  Individual    Colin      Campos   4/14/1942    M
# 159         159       C0113  Individual     Anya  Stephenson   6/11/1959    F
# 160         160       C0147  Individual   Parker       Poole  11/10/1951    M
# 161         161       C0133  Individual     Ivan      Bright   9/15/1953    M
#
# ...

# %%
# Generate profiling reports
customers_profile = ProfileReport(customers_df, title="Customers Profiling Report")

# %% [markdown]
# ### Properties Profiling

# %%
customers_profile.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-28 06:43:58.631612&quot;&gt;&lt;title&gt;Customers Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
